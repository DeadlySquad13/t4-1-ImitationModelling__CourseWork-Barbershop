# %%
from barbershop import BarberShopStatistics


barber_shop_statistics = BarberShopStatistics()
barber_shop_statistics.show()
# Out:
#  0.0000 Customer00 arrived
#  3.4551 Customer01 arrived
#  4.3830 Customer00 served in cashbox
#  4.3830 Customer00 arrived at  fashion hairdressing  queue
#  7.6001 Customer02 arrived
#  8.4868 Customer01 served in cashbox
#  8.4868 Customer01 arrived at  fashion hairdressing  queue
# 11.1518 Customer03 arrived
# 13.4476 Customer02 served in cashbox
# 13.4476 Customer02 arrived at  colouring  queue
# 14.5124 Customer04 arrived
# 17.1919 Customer03 served in cashbox
# 17.1919 Customer03 arrived at  short hairdressing  queue
# 17.9203 Customer05 arrived
# 20.2850 Customer02 got  colouring
# 20.2850 Customer02 arrived at  waiting after colouring  queue
# 21.2200 Customer04 served in cashbox
# 21.2200 Customer04 arrived at  colouring  queue
# 21.9346 Customer06 arrived
# 25.3785 Customer05 served in cashbox
# 25.3785 Customer05 arrived at  colouring  queue
# 25.4261 Customer07 arrived
# 29.4682 Customer08 arrived
# 30.2392 Customer06 served in cashbox
# ...

# %%
barber_shop_statistics.log()
# Out:
# Average cashbox one queue length = 	1.030806
# Average cashbox two queue length = 	1.000000
# Average short hairing queue length = 	1.010870
# Average fashion hairing queue length = 	8.837037
# Average colouring queue length = 	1.432558
# Cashbox one input intensity = 	0.225650
# Cashbox two input intensity = 	0.102594
# Short hairing hall input intensity = 	0.616425
# Fashion hairing hall input intensity = 	0.171690
# Colouring hall input intensity = 	0.814406
# Review desk input intensity = 	1.274413
# Average cashbox one waiting time = 	2.050926
# Average cashbox two waiting time = 	2.831159
# Average short hairing waiting time = 	3.610922
# Average fashion hairing waiting time =	 107.675330
# Average colouring waiting time = 	7.288034
# Average cashbox one presence time = 	6.186239
# Average cashbox two presence time = 	4.434740
# Average short hairing presence time = 	22.682307
# Average fashion hairing presence time = 	158.445534
# Average colouring presence time = 	12.050729
# ...

# %%
import find_optimal_number_of_clients

find_optimal_number_of_clients.find_optimal_number_of_clients()
# Out:
#    number of clients |   interval width (%) |   efficiency criterion
# --------------------------------------------------------------------
# -
# -
# -
# -
# -
#                 1000 |              25.5205 |      21.7082 ±  5.5400
#                 1100 |              16.5917 |      22.7396 ±  3.7729
#                 1200 |              15.6506 |      23.5618 ±  3.6876
#                 1300 |              19.0571 |      23.5824 ±  4.4941
#                 1400 |              21.0965 |      23.8164 ±  5.0244
#                 1500 |              21.3831 |      23.6508 ±  5.0573
#                 1600 |              32.5905 |      23.4770 ±  7.6513
#                 1700 |              16.1049 |      23.4181 ±  3.7715
#                 1800 |              15.8482 |      24.0375 ±  3.8095
#                 1900 |              21.5953 |      24.0726 ±  5.1985
#                 2000 |              12.3357 |      24.3866 ±  3.0082
# ...
