# %%
from barbershop import BarberShopStatistics


barber_shop_statistics = BarberShopStatistics()
barber_shop_statistics.show()

# %%
import find_optimal_number_of_clients

find_optimal_number_of_clients.find_optimal_number_of_clients()
# Out:
#    number of clients |   interval width (%) |   efficiency criterion
# --------------------------------------------------------------------
# -
# -
# -
# -
# -
#                 1000 |              36.6860 |      20.2702 ±  7.4363
#                 1100 |              24.6201 |      21.3528 ±  5.2571
#                 1200 |              22.8289 |      21.3617 ±  4.8766
#                 1300 |              17.5243 |      22.1559 ±  3.8827
#                 1400 |              27.2061 |      22.7671 ±  6.1941
#                 1500 |              28.7583 |      22.8404 ±  6.5685
#                 1600 |              14.8688 |      22.8446 ±  3.3967
#                 1700 |              15.0580 |      23.4128 ±  3.5255
#                 1800 |              18.4795 |      23.3897 ±  4.3223
#                 1900 |              16.1940 |      23.1087 ±  3.7422
#                 2000 |              15.2717 |      23.4537 ±  3.5818
#                 2100 |              20.8418 |      23.4807 ±  4.8938
#                 2200 |              15.0117 |      24.0289 ±  3.6071
#                 2300 |              21.2287 |      23.8989 ±  5.0734
#                 2400 |              10.8605 |      24.1927 ±  2.6274
#                 2500 |              15.0181 |      24.2282 ±  3.6386
#                 2600 |              16.0993 |      24.5966 ±  3.9599
#                 2700 |              12.7908 |      24.5081 ±  3.1348
#                 2800 |               8.6762 |      24.9117 ±  2.1614
#                 2900 |              14.6943 |      25.0410 ±  3.6796
#                 3000 |               3.3218 |      25.1278 ±  0.8347
#                 3100 |               8.0941 |      25.0459 ±  2.0272
#                 3200 |               6.3347 |      25.0824 ±  1.5889
#                 3300 |              12.5470 |      25.2289 ±  3.1655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import find_optimal_number_of_clients
# ----> 3 find_optimal_number_of_clients.find_optimal_number_of_clients()
#
# File ~\.bookmarks\Projects\--educational\Bomonka\ImitationModelling__\CourseWork@Barbershop\simpy\find_optimal_number_of_clients.py:104, in find_optimal_number_of_clients()
#     101     print("%20i | %20.4f | %22s" % (constants.number_of_clients, common_accuracy*100,
#     102                                 "%7.4f ± %7.4f" % (general_mean,general_interval_width+interval_width)))
#     103 if (common_accuracy > constants.minimal_accuracy):
# --> 104     winsound.Beep(500, 1000)
#     105 else:
#     106     winsound.Beep(2500, 1000)
#
# KeyboardInterrupt:
